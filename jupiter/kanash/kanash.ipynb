# %%
a = 14
b = 5
c = a + b

# %%
print(c, b)
# Out:
# 19 5

# %%
b = 5

# %%
a = 14
b = 5
c = a + b
print(c)
# Out:
# 19

# %%
for i in range(100):
    print('Номер : ', i)
# Out:
# Номер :  0
# Номер :  1
# Номер :  2
# Номер :  3
# Номер :  4
# Номер :  5
# Номер :  6
# Номер :  7
# Номер :  8
# Номер :  9
# Номер :  10
# Номер :  11
# Номер :  12
# Номер :  13
# Номер :  14
# Номер :  15
# Номер :  16
# Номер :  17
# Номер :  18
# Номер :  19
# Номер :  20
# Номер :  21
# Номер :  22
# Номер :  23
# Номер :  24
# Номер :  25
# Номер :  26
# Номер :  27
# Номер :  28
# Номер :  29
# Номер :  30
# Номер :  31
# Номер :  32
# Номер :  33
# Номер :  34
# Номер :  35
# Номер :  36
# Номер :  37
# Номер :  38
# Номер :  39
# Номер :  40
# Номер :  41
# Номер :  42
# Номер :  43
# Номер :  44
# Номер :  45
# Номер :  46
# Номер :  47
# Номер :  48
# Номер :  49
# Номер :  50
# Номер :  51
# Номер :  52
# Номер :  53
# Номер :  54
# Номер :  55
# Номер :  56
# Номер :  57
# Номер :  58
# Номер :  59
# Номер :  60
# Номер :  61
# Номер :  62
# Номер :  63
# Номер :  64
# Номер :  65
# Номер :  66
# Номер :  67
# Номер :  68
# Номер :  69
# Номер :  70
# Номер :  71
# ...

# %% [markdown]
# # Вывод графиков

# %%
import matplotlib.pyplot as plt

# %%
x = [-2, -1, 0, 1, 2]
y = [4, 1, 0, 1, 4]

# %%
plt.plot(x,y)

# %%
! ping ya.ru
# Out:
# PING ya.ru (77.88.44.242): 56 data bytes
# 64 bytes from 77.88.44.242: icmp_seq=0 ttl=50 time=149.088 ms
# 64 bytes from 77.88.44.242: icmp_seq=1 ttl=50 time=120.159 ms
# 64 bytes from 77.88.44.242: icmp_seq=2 ttl=50 time=120.960 ms
# 64 bytes from 77.88.44.242: icmp_seq=3 ttl=50 time=122.377 ms
# 64 bytes from 77.88.44.242: icmp_seq=4 ttl=50 time=122.509 ms
# 64 bytes from 77.88.44.242: icmp_seq=5 ttl=50 time=122.775 ms
# 64 bytes from 77.88.44.242: icmp_seq=6 ttl=50 time=121.715 ms
# 64 bytes from 77.88.44.242: icmp_seq=7 ttl=50 time=121.587 ms
# 64 bytes from 77.88.44.242: icmp_seq=8 ttl=50 time=119.853 ms
# 64 bytes from 77.88.44.242: icmp_seq=9 ttl=50 time=120.257 ms
# 64 bytes from 77.88.44.242: icmp_seq=10 ttl=50 time=122.117 ms
# 64 bytes from 77.88.44.242: icmp_seq=11 ttl=50 time=122.529 ms
# 64 bytes from 77.88.44.242: icmp_seq=12 ttl=50 time=122.652 ms
# 64 bytes from 77.88.44.242: icmp_seq=13 ttl=50 time=120.119 ms
# ...

# %% [markdown]
# ## Подзаголовок

# %% [markdown]
# Обычный текст

# %% [markdown]
# **Жирный**

# %% [markdown]
# *курсив*

# %% [markdown]
# # Список

# %% [markdown]
# * One
# * Two
# * Three

# %% [markdown]
# ```python
# # можно приводить фрагменты кода
# from pprint import pprint

# %% [markdown]
# ## Можно делать таблицы

# %% [markdown]
# | This | is    |
# |------|-------|
# |   a  | table |

# %% [markdown]
# ### HTML теги

# %% [markdown]
# <h1>Header 1</h1>

# %% [markdown]
# # User
# Plot the first 100 fibonacci numbers

# %% [markdown]
# # Assistant
# # Plotting the First 100 Fibonacci Numbers
#
# To plot the first 100 Fibonacci numbers, I'll create a Python script that:
# 1. Generates the Fibonacci sequence
# 2. Plots the numbers using matplotlib
#
# Here's the code to accomplish this:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Function to generate Fibonacci sequence
def fibonacci(n):
    fib_sequence = [0, 1]
    for i in range(2, n):
        fib_sequence.append(fib_sequence[i-1] + fib_sequence[i-2])
    return fib_sequence

# Generate the first 100 Fibonacci numbers
n = 100
fib_numbers = fibonacci(n)

# Create indices for x-axis
indices = list(range(n))

# Create the plot
plt.figure(figsize=(12, 6))
plt.plot(indices, fib_numbers, marker='o', linestyle='-', markersize=3)
plt.title('First 100 Fibonacci Numbers')
plt.xlabel('Index')
plt.ylabel('Value')
plt.grid(True)

# Add a logarithmic scale for y-axis since Fibonacci numbers grow exponentially
plt.yscale('log')

# Show the plot
plt.tight_layout()
plt.show()

# Print the last few numbers to see the scale
print(f"The 100th Fibonacci number is: {fib_numbers[-1]:,}")
# Out:
# The 100th Fibonacci number is: 218,922,995,834,555,169,026

# %% [markdown]
# This code:
# - Defines a function to generate Fibonacci numbers
# - Creates a sequence of the first 100 Fibonacci numbers
# - Plots them with matplotlib using a logarithmic scale (since Fibonacci numbers grow exponentially)
# - Adds appropriate labels and formatting
#
# The logarithmic scale is important because the 100th Fibonacci number is extremely large compared to the first few numbers, making it difficult to visualize the entire sequence on a linear scale.
